# %% [markdown]
# # CHAT GPT Model Fine tuning

# %%
import os
import csv
import json

# %%
# # Read CSV file
# with open('chat_gpt_data.csv', 'r') as f:
#     data = list(csv.reader(f))
#     headers = data[0]
#     data = data[1:]

# # Create prompt and completion pairs
# pairs = []
# for patient in data:
#     prompt = f"Write a summary of {patient[headers.index('patient')]}'s statistics:"
#     #completion = f"{patient[headers.index('patient')]} played {player[headers.index('GP  Games played')]} games, starting {player[headers.index('GS  Games started')]} of them. He had an average of {player[headers.index('MPG  Minutes Per Game')]} minutes per game, scoring {player[headers.index('PPG  Points Per Game')]} points per game. He made {player[headers.index('FGM  Field Goals Made')]} out of {player[headers.index('FGA  Field Goals Attempted')]} field goals, for a field goal percentage of {player[headers.index('FG%  Field Goal Percentage')]}. He made {player[headers.index('3FGM  Three-Point Field Goals Made')]} out of {player[headers.index('3FGA  Three-Point Field Goals Attempted')]} three-point field goals, for a three-point field goal percentage of {player[headers.index('3FG%  Three-Point Field Goal Percentage')]}. He made {player[headers.index('FTM  Free Throws Made')]} out of {player[headers.index('FTA  Free Throws Attempted')]} free throws, for a free throw percentage of {player[headers.index('FT%  Free Throw Percentage')]}. He plays as {player[headers.index('Position')]} for the {player[headers.index('Team')]}."
#     completion = f"{patient[headers.index('patient')]} lives in {patient[headers.index('addresscity')]} payment is done through {patient[headers.index('paymentmethod')]} . Patient's date of birth is  {patient[headers.index('dob')]}. Patient's marritial status is  {patient[headers.index('maritalstatus')]}. Patient is  {patient[headers.index('gender')]}. patient is coming from  {patient[headers.index('ethnicity')]} community. Recorded occupation of the patient is {patient[headers.index('occupation')]}."

#     pairs.append({"prompt": prompt, "completion": completion})

# # Export to JSON file
# with open('prompt_completion_pairs.json', 'w') as f:
#     json.dump(pairs, f)

# %%
# with open('prompt_completion_pairs.json', 'r') as json_file:
#     data = json.load(json_file)

# with open('output_file4.jsonl', 'w') as jsonl_file:
#     for item in data:
#         jsonl_file.write(json.dumps(item) + '\n')

# %%
## Data Tuning
openai tools fine_tunes.prepare_data -f 'output_file4.jsonl'

# %%
os.environ['OPENAI_API_KEY'] = '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'

# %%
## Model Tuning
openai api fine_tunes.create -t "output_file4_prepared.jsonl" -m davinci

# %%
import pandas as pd
import os
os.chdir("C:/Users/p_adi/Downloads")

# %%
data1 = pd.read_excel('appianrx_adherrence_data.xlsx')
data1.head()
# Out:
#    storenbr    rxnbr  rfnbr  dispenseddrugstoreid  dispenseddrugkey  \
# 0    103237   446697      2                   NaN             19279
# 1    103237   446698      0                   NaN             22771
# 2    101867  1083372      3                   NaN             24135
# 3    103237   446679      2                   NaN             25329
# 4    103237   460259      2                   NaN              7328
#
#    orderdate   filldate  dispensedqty1  rxqty  daysupp  ...  SSRXNBR  \
# 0 2017-04-17 2017-04-17            120     30       40  ...   145292
# 1 2017-04-17 2017-04-17            300     60      150  ...   145294
# 2 2019-03-01 2019-03-04              4      1        4  ...   464187
# 3 2017-04-17 2017-04-17            240     60       60  ...   145289
# 4 2017-08-07 2017-09-01             90     30       90  ...   201637
#
#       Rx_key  FirstFillDate  LastFillDate  DaysWithNoMedicine  totalSupply  \
# ...

# %%
data2 = data1.sample(1000)
data2.to_excel('adherence.xlsx')

# %%
import pandas as pd
import os

os.chdir('C:/Users/p_adi')
# Load the patient data from the CSV file
patient_data = pd.read_csv("relapse_kipu.csv")
patient_data.head()
# Out:
#   patientmasterkey programname        care_level  levelofcare_los censustype  \
# 0          996_333         PHP  NO LEVEL OF CARE              618   Enrolled
# 1          996_333         PHP  NO LEVEL OF CARE              625   Enrolled
# 2          996_333         PHP  NO LEVEL OF CARE              726   Enrolled
# 3          996_333         PHP  NO LEVEL OF CARE              607   Enrolled
# 4          996_333         PHP  NO LEVEL OF CARE              689   Enrolled
#
#       height     weight diagcode census_date diag_label  diag_count
# 0  NO HEIGHT  NO WEIGHT    Z65.0  30-10-2021      other           1
# 1  NO HEIGHT  NO WEIGHT  F14.120  06-11-2021      other           1
# 2  NO HEIGHT  NO WEIGHT  F14.120  15-02-2022      other           1
# 3  NO HEIGHT  NO WEIGHT    F33.1  19-10-2021     severe           1
# 4  NO HEIGHT  NO WEIGHT    Z63.5  09-01-2022      other           1

# %%
# Define a function to apply the label to each diagnosis code
def label_diagnosis_code(diagcode):
    if diagcode.startswith(('F20.', 'F31.', 'F32.3', 'F33.', 'F41.1', 'F42.', 'F43.21')):
        return 'severe'
    elif diagcode.startswith(('F40.', 'F43.0', 'F43.10', 'F44.', 'F48.0')):
        return 'less severe'
    else:
        return 'other'

# Apply the label to each diagnosis code
patient_data['diag_label'] = patient_data['diagcode'].apply(label_diagnosis_code)

# Group the data by patient ID and concatenate the labels for each record
grouped_data = patient_data.groupby('patientmasterkey')['diag_label'].apply(lambda x: ','.join(x)).reset_index()

# Split the concatenated labels and count the number of occurrences of each label for each patient
grouped_data['label_list'] = grouped_data['diag_label'].str.split(',')
grouped_data = grouped_data.explode('label_list')
grouped_data = grouped_data.groupby(['patientmasterkey', 'label_list']).size().reset_index(name='count')

# Find the label with the maximum count for each patient
grouped_data = grouped_data.sort_values(['patientmasterkey', 'count'], ascending=[True, False])
grouped_data = grouped_data.groupby('patientmasterkey').first().reset_index()

# Merge the data back with the original patient data
result = pd.merge(patient_data.drop(columns='diag_label'), grouped_data, on='patientmasterkey')

# %%
result.head()
# Out:
#   patientmasterkey programname        care_level  levelofcare_los censustype  \
# 0          996_333         PHP  NO LEVEL OF CARE              618   Enrolled
# 1          996_333         PHP  NO LEVEL OF CARE              625   Enrolled
# 2          996_333         PHP  NO LEVEL OF CARE              726   Enrolled
# 3          996_333         PHP  NO LEVEL OF CARE              607   Enrolled
# 4          996_333         PHP  NO LEVEL OF CARE              689   Enrolled
#
#       height     weight diagcode census_date  diag_count label_list  count
# 0  NO HEIGHT  NO WEIGHT    Z65.0  30-10-2021           1      other   5485
# 1  NO HEIGHT  NO WEIGHT  F14.120  06-11-2021           1      other   5485
# 2  NO HEIGHT  NO WEIGHT  F14.120  15-02-2022           1      other   5485
# 3  NO HEIGHT  NO WEIGHT    F33.1  19-10-2021           1      other   5485
# 4  NO HEIGHT  NO WEIGHT    Z63.5  09-01-2022           1      other   5485

# %%
result['diagcode'].value_counts()
# Out:
# F10.20     1833
# F33.1      1264
# Z65.0      1097
# Z63.5      1097
# F13.10     1097
# F14.120    1097
# F41.1       393
# F15.20      218
# F11.20      216
# F32.9       203
# F41.9       170
# F43.1       152
# F90.9       137
# (F33.9)     129
# F13.20      117
# F43.9        96
# F31.10       94
# F12.20       86
# F14.20       67
# F60.3        66
# F12.10       59
# F43.23       59
# F33.9        51
# F50.9        42
# F43.22       42
# (F41.9)      41
# F50.89       37
# F43.10       36
# F33.0         4
# Name: diagcode, dtype: int64

# %%
result['patientmasterkey'].value_counts()
# Out:
# 996_333    6582
# 992_985     396
# 992_984     284
# 992_986     255
# 992_991     236
# 992_988     222
# 992_993     210
# 992_987     188
# 992_983     168
# 992_976     162
# 992_990     156
# 992_978     142
# 992_982     130
# 992_996     130
# 992_989     128
# 992_997     120
# 992_995     112
# 992_992      96
# 992_994      72
# 992_981      64
# 992_980      64
# 992_998      35
# 992_999      32
# 992_979      16
# Name: patientmasterkey, dtype: int64

# %%
import openai

# Replace 'YOUR_API_KEY' with your actual API key from OpenAI
api_key = 'YOUR_API_KEY'

# Set up the API key
openai.api_key = api_key

# Define the prompt
prompt = "Create a grade 5 level math puzzle involving fractions."

# Use the OpenAI API to generate text
response = openai.Completion.create(
    engine="text-davinci-002",  # Choose the relevant GPT-3 engine
    prompt=prompt,
    max_tokens=100,  # Adjust the number of tokens in the generated text
    temperature=0.7,  # Adjust the temperature for creativity
)

# Get the generated puzzle from the API response
generated_puzzle = response['choices'][0]['text']

# Filter and evaluate the generated puzzle
# (Additional Python code required)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import openai
#       3 # Replace 'YOUR_API_KEY' with your actual API key from OpenAI
#       4 api_key = 'YOUR_API_KEY'
#
# File ~\anaconda3\lib\site-packages\openai\__init__.py:9
#       6 from contextvars import ContextVar
#       7 from typing import Optional, TYPE_CHECKING
# ----> 9 from openai.api_resources import (
#      10     Completion,
#      11     Customer,
#      12     Edit,
#      13     Deployment,
#      14     Embedding,
#      15     Engine,
#      16     ErrorObject,
#      17     File,
#      18     FineTune,
#      19     Image,
#      20     Model,
#      21     Moderation,
#      22 )
#      23 from openai.error import APIError, InvalidRequestError, OpenAIError
#      25 if TYPE_CHECKING:
#
# File ~\anaconda3\lib\site-packages\openai\api_resources\__init__.py:1
# ...

# %%
pip show matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Error processing line 3 of C:\Users\p_adi\anaconda3\lib\site-packages\googleapis_common_protos-1.57.0-py3.9-nspkg.pth:
#
#   Traceback (most recent call last):
#     File "C:\Users\p_adi\anaconda3\lib\site.py", line 169, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#     File "<frozen importlib._bootstrap>", line 562, in module_from_spec
#   AttributeError: 'NoneType' object has no attribute 'loader'
#
# Remainder of file ignored
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\p_adi\anaconda3\lib\site-packages)
# WARNING: Package(s) not found: matplotlib
